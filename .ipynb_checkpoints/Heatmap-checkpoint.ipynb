# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from  matplotlib.colors import LinearSegmentedColormap
import matplotlib.colors as colors

# %%
df = pd.read_csv('table_numbers.csv')
df = df.drop(['Overall'], axis=1)
df = df.set_index('state')
df.fillna(value=np.nan, inplace=True)

# %%
df
# Out:
#                        Alcohol  Benzodiapenes   Cocaine    Heroin  \
# state
# Alabama               0.915554      -0.017692  0.736424 -0.375675
# Alaska                0.000000       1.363529  1.363529 -3.545176
# Arizona               0.268271       0.475425  0.349577  0.433475
# Arkansas              1.233971       1.121616  0.215976 -0.488098
# California            0.758759       0.783529  0.144164 -0.354088
# Colorado             -0.211689       0.681248  0.942621 -0.094062
# Connecticut           1.948766      -0.998352  0.187961 -3.632891
# Delaware             -2.424370       3.232493 -4.848740  1.616247
# District of Columbia -2.175348       1.127743 -1.450232 -1.160185
# Florida               1.592520       0.886797  1.378946 -0.329647
# Georgia               0.998888       1.484329  0.224050  0.821516
# Hawaii                0.068716       0.274863  0.487642  0.206147
# Idaho                -0.598117       0.199372       NaN -0.002227
# Illinois              0.478698       1.373658  1.147316  1.162926
# Indiana               0.193221       1.267403  0.206321 -1.326352
# Iowa                  0.625292       0.585093  0.031344  0.960367
# Kansas                1.085438       1.361526  0.226921 -0.578649
# Kentucky              1.011033       3.750691  1.664508 -0.998705
# Louisiana            -0.236165       1.316793  2.554878  0.446090
# Maine                 1.019473       0.000000  0.367010  0.513815
# Maryland              1.545102       0.790604  0.679917  1.068441
# Massachusetts         0.640121       1.664316  1.038419 -0.739696
# Michigan              0.456470       1.111405  0.853401  1.379333
# Minnesota             0.311534       0.911243  0.496186  0.240550
# Mississippi           0.607845      -0.270154  0.438999 -1.553383
# Missouri              0.638530       0.039911  0.747370 -2.035710
# Montana               1.567940            NaN       NaN       NaN
# Nebraska              1.288678       0.821365       NaN       NaN
# Nevada                0.930873       2.272601  0.727257 -0.354311
# New Hampshire        -0.959852      -2.185879 -2.290736       NaN
# New Jersey            0.290667      -0.129185 -0.172247 -0.376790
# New Mexico            0.991725       1.004090  1.701713 -2.266801
# New York              1.831570       1.791968  2.049378  1.113793
# North Carolina        1.623125       0.258636  1.388970 -0.229899
# North Dakota         -2.310376            NaN       NaN       NaN
# Ohio                  0.552755       0.669523 -0.840906 -0.161024
# Oklahoma              0.631416       0.263790  0.555646  0.555646
# Oregon                0.165201       0.463602 -0.613605  1.392411
# Pennsylvania          0.677927       0.504239 -0.184577  0.130742
# Rhode Island         -0.263255       3.742295  3.966449       NaN
# South Carolina        2.344471       0.410282  3.243185  0.879177
# South Dakota          1.578947            NaN       NaN       NaN
# Tennessee             2.281439       3.154465  1.168856 -0.998431
# Texas                 0.632712       0.977852  0.933249 -0.044604
# Utah                  0.354637       1.314335  0.227546 -0.194435
# Vermont              -0.870802            NaN  2.332536 -3.365159
# Virginia              1.633571       1.092472  1.818942 -0.440253
# Washington            0.644579       0.999575  0.692166  0.402321
# West Virginia         3.846763      12.599542 -0.167251  2.899010
# Wisconsin             1.847541       2.553769  1.645820  0.322377
# Wyoming              -1.040132       0.238363       NaN       NaN
#
#                       Methamphetamine  Synthetic Opioids
# state
# Alabama                     -0.238840           3.383570
# Alaska                       1.605934           5.438966
# Arizona                      2.502971           6.553402
# Arkansas                     2.022847           1.992347
# California                   2.954103           3.889907
# Colorado                     2.961698           3.827692
# Connecticut                  0.494584           0.083196
# Delaware                          NaN          -2.525385
# District of Columbia              NaN          -0.795521
# Florida                      1.304659           5.525070
# Georgia                      1.210342           4.896139
# Hawaii                       0.893304           0.848896
# Idaho                        0.255731           1.141859
# Illinois                     1.303414           4.878046
# Indiana                      1.149505           8.650764
# Iowa                        -2.100071           2.441103
# Kansas                      -1.497679           2.416709
# Kentucky                     4.926944          13.537998
# Louisiana                    2.104017           5.947069
# Maine                        2.128661           2.422269
# Maryland                     0.728483           5.131755
# Massachusetts                0.625896           0.455197
# Michigan                     1.240408           5.935214
# Minnesota                    0.490669           3.924105
# Mississippi                  2.330074           6.021844
# Missouri                     1.169797           5.085368
# Montana                     -3.035934           1.652260
# Nebraska                     1.520440           2.396121
# Nevada                       1.225867           4.670468
# New Hampshire                1.256122           1.016313
# New Jersey                  -0.279901           1.216493
# New Mexico                   0.215765           6.719981
# New York                     0.826521           6.133284
# North Carolina               1.714660           7.998553
# North Dakota                 1.583132           2.376686
# Ohio                         0.050850           5.661282
# Oklahoma                     2.323612           1.826897
# Oregon                       0.660805           3.587227
# Pennsylvania                 0.912604           5.260446
# Rhode Island                 0.655058           9.112622
# South Carolina               2.168636          10.511046
# South Dakota                -2.030074           2.444999
# Tennessee                    2.127093           8.264257
# Texas                        0.703367           2.058244
# Utah                        -0.516225           1.776220
# Vermont                           NaN           6.997607
# Virginia                     1.726257           6.453188
# Washington                   1.429944           2.542728
# West Virginia                8.641279          26.091087
# Wisconsin                    1.607839           4.598116
# Wyoming                      0.173355           2.616402

# %%
cmap=LinearSegmentedColormap.from_list('op',["#912cee", "w", "#ff7800"], N=256)
fig, ax = plt.subplots()
g = sns.heatmap(df, cmap = cmap, center = 0, vmax = 15, mask=data > 1.3)
g.set_facecolor('#B2B2B2')
sns.set(rc = {'figure.figsize':(3,30)})
plt.show()

# %%
class MidpointNormalize(colors.Normalize):
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        # I'm ignoring masked values and all kinds of edge cases to make a
        # simple example...
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y))

# %%
fig, ax = plt.subplots()
im = ax.imshow(df, cmap=cmap, interpolation='none', vmax=15, norm = MidpointNormalize(midpoint = 0, vmax = 15))
cbar = fig.colorbar(im, extend='max')
cbar.cmap.set_over('red')

plt.show()
